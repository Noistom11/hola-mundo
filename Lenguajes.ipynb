# %% [markdown]
# <a href="https://colab.research.google.com/github/Noistom11/hola-mundo/blob/master/Lenguajes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**1) Lenguaje C**
# `Como hacer hola mundo en C`

# %%
#include <stdio.h>
int main() {
    printf("Hola mundo");
    return 0;
}
# Out:
# Overwriting hello.c

# %% [markdown]
# #**2) Lenguaje Python**
# `Hola mundo en Python`

# %%
print("Hola, mundo!")
# Out:
# Hola, mundo!

# %% [markdown]
# #**3) Lenguaje Java**
# `Hola mundo en Java`

# %%
public class HolaMundo {
    public static void main(String[] args) {
        System.out.println("¡Hola Mundo!");
    }
}
